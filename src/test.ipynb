# %%
from components.database_and_retriever import vectorstore_processing_and_retriever
import matplotlib.pyplot as plt
import pickle

# %%
hybrid_retriever = vectorstore_processing_and_retriever()
# Out:
# d:\Kinnovia documents\Code Implementations\CRAG\Corrective-RAG\src\components\database_and_retriever.py:20: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vector_store = Chroma(

# %%
out = hybrid_retriever.invoke("What does ASPICE SYS.2 require?")

# %%
out
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2016', 'source': 'D:/Kinnovia documents/Code Implementations/CRAG/Corrective-RAG/src/documents\\Automotive_SPICE_PAM_31_EN.pdf', 'total_pages': 128, 'page_label': '126', 'creationdate': '2017-10-30T22:27:00+01:00', 'creator': 'Microsoft® Word 2016', 'author': 'Jan', 'moddate': '2023-02-20T15:23:43+01:00', 'page': 125}, page_content='© VDA Quality Management Center 126 \n \n \nSWE.3.BP4: Evaluate\nSYS.3.BP5: Evaluate\nSWE.2.BP6: Evaluate\nSYS.2\nSystem Requirements \nAnalysis\nSYS.3\nSystem Architectural \nDesign\nSYS.4\nSystem Integration and \nIntegration Test\nSYS.5\nSystem Qualification Test\nSWE.1\nSoftware Requirements \nAnalysis\nSWE.2\nSoftware Architectural \nDesign\nSWE.3\nSoftware Detailed Design \nand Unit Construction\nSWE.4\nSoftware Unit Verification\nSWE.5\nSoftware Integration and \nIntegration Test\nSWE.6\nSoftware Qualification Test'),
# ...

# %%
# Measure chunk sizes (character length)
chunk_sizes = [len(doc.page_content) for doc in chunks]

# Plot bar chart
plt.figure(figsize=(8, 5))
plt.bar(range(1, len(chunk_sizes) + 1), chunk_sizes)
plt.xlabel("Chunk Index")
plt.ylabel("Chunk Size (characters)")
plt.title("Chunk Sizes Returned by Retriever")
plt.show()
