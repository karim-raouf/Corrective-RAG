# %%
# !pip install langchain-docling
# Out:
# ...
#   Using cached langchain_docling-1.0.0-py3-none-any.whl.metadata (4.1 kB)
# ...
# Using cached langchain_docling-1.0.0-py3-none-any.whl (5.6 kB)
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from CRAG_Graph import graph
# Out:
# c:\Users\karim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_path" in LayoutModelConfig has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# c:\Users\karim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_spec" in LayoutOptions has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# ...

# %%
#List the base practices for MAN.3 Project Management process
output = graph.invoke({"question": "The process SUP.8 Configuration Management requires developing a strategy in its base practice SUP.8.BP1. This is captured in the work product '08-04 Configuration management plan'. According to Annex B, what are the key characteristics that this plan must define?"})
print("final answer: --------------------------------------------------")
print(output["final_output"])

# %%
# Measure chunk sizes (character length)
chunk_sizes = [len(doc.page_content) for doc in chunks]

# Plot bar chart
plt.figure(figsize=(8, 5))
plt.bar(range(1, len(chunk_sizes) + 1), chunk_sizes)
plt.xlabel("Chunk Index")
plt.ylabel("Chunk Size (characters)")
plt.title("Chunk Sizes Returned by Retriever")
plt.show()
